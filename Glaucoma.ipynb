# %% [markdown]
# <a href="https://colab.research.google.com/github/vikrutisrija/Python/blob/main/Glaucoma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn import preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/glaucoma - glaucoma.csv')

# %%
data
# Out:
#     Filename  ExpCDR Eye Set  Glaucoma
# 0    001.jpg  0.7097  OD   A         0
# 1    002.jpg  0.6953  OS   A         0
# 2    003.jpg  0.9629  OS   A         0
# 3    004.jpg  0.7246  OD   A         0
# 4    005.jpg  0.6138  OS   A         0
# ..       ...     ...  ..  ..       ...
# 645  646.jpg  0.6560  OD   A         1
# 646  647.jpg  0.7365  OD   A         1
# 647  648.jpg  0.5101  OS   A         1
# 648  649.jpg  0.5227  OD   B         0
# 649  650.jpg  0.6195  OS   B         1
#
# [650 rows x 5 columns]

# %%
data.shape
# Out:
# (650, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Filename  650 non-null    object
#  1   ExpCDR    650 non-null    float64
#  2   Eye       650 non-null    object
#  3   Set       650 non-null    object
#  4   Glaucoma  650 non-null    int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 25.5+ KB

# %%
data.head()
# Out:
#   Filename  ExpCDR Eye Set  Glaucoma
# 0  001.jpg  0.7097  OD   A         0
# 1  002.jpg  0.6953  OS   A         0
# 2  003.jpg  0.9629  OS   A         0
# 3  004.jpg  0.7246  OD   A         0
# 4  005.jpg  0.6138  OS   A         0

# %%
data.tail()
# Out:
#     Filename  ExpCDR Eye Set  Glaucoma
# 645  646.jpg  0.6560  OD   A         1
# 646  647.jpg  0.7365  OD   A         1
# 647  648.jpg  0.5101  OS   A         1
# 648  649.jpg  0.5227  OD   B         0
# 649  650.jpg  0.6195  OS   B         1

# %%
data.describe()
# Out:
#            ExpCDR    Glaucoma
# count  650.000000  650.000000
# mean     0.576308    0.258462
# std      0.116395    0.438126
# min      0.161000    0.000000
# 25%      0.496675    0.000000
# 50%      0.567650    0.000000
# 75%      0.648475    1.000000
# max      0.962900    1.000000

# %%
data["Eye"].value_counts()
# Out:
# OD    327
# OS    323
# Name: Eye, dtype: int64

# %%
data["Set"].value_counts()
# Out:
# A    325
# B    325
# Name: Set, dtype: int64

# %%
data["Glaucoma"].value_counts()
# Out:
# 0    482
# 1    168
# Name: Glaucoma, dtype: int64

# %%
data["ExpCDR"].value_counts()
# Out:
# 0.4986    5
# 0.5333    3
# 0.6563    3
# 0.5313    3
# 0.6057    3
#          ..
# 0.6694    1
# 0.5120    1
# 0.4933    1
# 0.5812    1
# 0.5227    1
# Name: ExpCDR, Length: 583, dtype: int64

# %%
print("The Highest Age in the Data Set was Of: ",data["ExpCDR"].max())
print("The Lowest Age in the Data Set was Of: ",data["ExpCDR"].min())
print("The Average Age in the Data Set was Of: ",data["ExpCDR"].mean())
# Out:
# The Highest Age in the Data Set was Of:  0.9629
# The Lowest Age in the Data Set was Of:  0.161
# The Average Age in the Data Set was Of:  0.5763076923076923

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 645    False
# 646    False
# 647    False
# 648    False
# 649    False
# Length: 650, dtype: bool

# %%
data.drop_duplicates()
# Out:
#     Filename  ExpCDR Eye Set  Glaucoma
# 0    001.jpg  0.7097  OD   A         0
# 1    002.jpg  0.6953  OS   A         0
# 2    003.jpg  0.9629  OS   A         0
# 3    004.jpg  0.7246  OD   A         0
# 4    005.jpg  0.6138  OS   A         0
# ..       ...     ...  ..  ..       ...
# 645  646.jpg  0.6560  OD   A         1
# 646  647.jpg  0.7365  OD   A         1
# 647  648.jpg  0.5101  OS   A         1
# 648  649.jpg  0.5227  OD   B         0
# 649  650.jpg  0.6195  OS   B         1
#
# [650 rows x 5 columns]

# %%
newdata=data.fillna(method="bfill")

# %%
plt.plot(newdata['ExpCDR'])
plt.xlabel("Eye")
plt.ylabel("Glaucoma")
# Out:
# Text(0, 0.5, 'Glaucoma')

# %%
newdata.describe()
# Out:
#            ExpCDR    Glaucoma
# count  650.000000  650.000000
# mean     0.576308    0.258462
# std      0.116395    0.438126
# min      0.161000    0.000000
# 25%      0.496675    0.000000
# 50%      0.567650    0.000000
# 75%      0.648475    1.000000
# max      0.962900    1.000000

# %%
newdata.shape
# Out:
# (650, 5)

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(13,5))
data_len=data[data['Glaucoma']==1]['ExpCDR'].value_counts()

ax1.hist(data_len,color='red')
ax1.set_title('Having Glaucoma')

data_len=data[data['Glaucoma']==0]['ExpCDR'].value_counts()
ax2.hist(data_len,color='blue')
ax2.set_title('NOT Having Glaucoma')

fig.suptitle('Glaucoma Levels')
plt.show()

# %%
data.isnull().sum()
# Out:
# Filename    0
# ExpCDR      0
# Eye         0
# Set         0
# Glaucoma    0
# dtype: int64

# %%
data[1:6]
# Out:
#   Filename  ExpCDR Eye Set  Glaucoma
# 1  002.jpg  0.6953  OS   A         0
# 2  003.jpg  0.9629  OS   A         0
# 3  004.jpg  0.7246  OD   A         0
# 4  005.jpg  0.6138  OS   A         0
# 5  006.jpg  0.6451  OD   B         0

# %%
from sklearn.preprocessing import LabelEncoder # converts gender into numbers
label_encoder = LabelEncoder()
categorical_cols_to_encode = ['Eye']
for col in categorical_cols_to_encode:
    newdata[col] = label_encoder.fit_transform(newdata[col])
newdata.head()
# Out:
#   Filename  ExpCDR  Eye Set  Glaucoma
# 0  001.jpg  0.7097    0   A         0
# 1  002.jpg  0.6953    1   A         0
# 2  003.jpg  0.9629    1   A         0
# 3  004.jpg  0.7246    0   A         0
# 4  005.jpg  0.6138    1   A         0

# %%
from sklearn.preprocessing import LabelEncoder # converts gender into numbers
label_encoder = LabelEncoder()
categorical_cols_to_encode = ['Set']
for col in categorical_cols_to_encode:
    newdata[col] = label_encoder.fit_transform(newdata[col])
newdata.head()
# Out:
#   Filename  ExpCDR  Eye  Set  Glaucoma
# 0  001.jpg  0.7097    0    0         0
# 1  002.jpg  0.6953    1    0         0
# 2  003.jpg  0.9629    1    0         0
# 3  004.jpg  0.7246    0    0         0
# 4  005.jpg  0.6138    1    0         0

# %%
from sklearn import preprocessing
import pandas as pd
d = preprocessing.normalize(newdata.iloc[:,1:4], axis=1)
scaled_df = pd.DataFrame(d, columns=["ExpCDR", "Set","Eye"])
scaled_df.head()
# Out:
#      ExpCDR       Set  Eye
# 0  1.000000  0.000000  0.0
# 1  0.570870  0.821041  0.0
# 2  0.693618  0.720343  0.0
# 3  1.000000  0.000000  0.0
# 4  0.523118  0.852261  0.0

# %%
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix#for confusion matrix
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression,LinearRegression #logistic regression

# %%
import pandas as pd
filename_mapping = {filename: index for index, filename in enumerate(newdata['Filename'])}
newdata['Filename'] = newdata['Filename'].map(filename_mapping)
print(newdata)
# Out:
#      Filename  ExpCDR  Eye  Set  Glaucoma
# 0           0  0.7097    0    0         0
# 1           1  0.6953    1    0         0
# 2           2  0.9629    1    0         0
# 3           3  0.7246    0    0         0
# 4           4  0.6138    1    0         0
# ..        ...     ...  ...  ...       ...
# 645       645  0.6560    0    0         1
# 646       646  0.7365    0    0         1
# 647       647  0.5101    1    0         1
# 648       648  0.5227    0    1         0
# 649       649  0.6195    1    1         1
#
# [650 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder # converts gender into numbers
label_encoder = LabelEncoder()
categorical_cols_to_encode = ['Filename']
for col in categorical_cols_to_encode:
    newdata[col] = label_encoder.fit_transform(newdata[col])
newdata.head()
# Out:
#    Filename  ExpCDR  Eye  Set  Glaucoma
# 0         0  0.7097    0    0         0
# 1         1  0.6953    1    0         0
# 2         2  0.9629    1    0         0
# 3         3  0.7246    0    0         0
# 4         4  0.6138    1    0         0

# %%
train,test=train_test_split(newdata,test_size=0.3,random_state=0,stratify=newdata['Glaucoma'])
train_X=train[train.columns[:-1]]
train_Y=train[train.columns[-1:]]
test_X=test[test.columns[:-1]]
test_Y=test[test.columns[-1:]]
X=newdata[newdata.columns[:-1]]
Y=newdata['Glaucoma']
len(train_X), len(train_Y), len(test_X), len(test_Y)
# Out:
# (455, 455, 195, 195)

# %%
model = LogisticRegression()
model.fit(train_X,train_Y)
prediction3=model.predict(test_X)
print('The accuracy of the Logistic Regression is',metrics.accuracy_score(prediction3,test_Y))
report = classification_report(test_Y, prediction3)
print("Classification Report:\n", report)
# Out:
# The accuracy of the Logistic Regression is 0.8102564102564103
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.98      0.88       145
#            1       0.84      0.32      0.46        50
#
#     accuracy                           0.81       195
#    macro avg       0.82      0.65      0.67       195
# weighted avg       0.82      0.81      0.78       195

# %%
model = LinearRegression()
model.fit(train_X, train_Y)
prediction = model.predict(test_X)

# Assuming 'test_Y' contains the true labels for the test set
# Calculate the accuracy
accuracy = accuracy_score(test_Y, prediction.round())

# Print the accuracy
print('The accuracy of Linear Regression is:', accuracy)
# Out:
# The accuracy of Linear Regression is: 0.7948717948717948
